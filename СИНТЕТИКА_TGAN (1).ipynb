# %%
import pandas as pd

# %%
fich_1 =  pd.read_csv("/content/Dataset.csv")
fich_1
# Out:
#         Type  url_length  number_of_dots_in_url  \
# 0          0          37                      2
# 1          1          70                      5
# 2          0          42                      2
# 3          0          46                      2
# 4          0          51                      3
# ...      ...         ...                    ...
# 247945     0          42                      1
# 247946     0          42                      2
# 247947     1          33                      2
# 247948     1          83                      1
# 247949     0          34                      3
#
#         having_repeated_digits_in_url  number_of_digits_in_url  \
# 0                                   0                        0
# 1                                   0                        0
# 2                                   0                        6
# 3                                   0                        0
# 4                                   0                        0
# ...

# %%
fich_small = fich_1.head(101)
fich_small
# Out:
#      Type  url_length  number_of_dots_in_url  having_repeated_digits_in_url  \
# 0       0          37                      2                              0
# 1       1          70                      5                              0
# 2       0          42                      2                              0
# 3       0          46                      2                              0
# 4       0          51                      3                              0
# ..    ...         ...                    ...                            ...
# 96      0          36                      2                              0
# 97      0          57                      2                              0
# 98      0          42                      2                              0
# 99      0          52                      3                              0
# 100     1          39                      2                              0
#
# ...

# %%
fich_small['Type'].value_counts()
# Out:
# Type
# 0    63
# 1    38
# Name: count, dtype: int64

# %%
pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 860.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
pip install ctgan
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.9 MB/s eta 0:00:00
# ...

# %%
fich_small['Type']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 96     0
# 97     0
# 98     0
# 99     0
# 100    1
# Name: Type, Length: 101, dtype: int64

# %%
import seaborn as sns
import pandas as pd
from ctgan import CTGAN
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-a73171c45dd9> in <cell line: 0>()
#       9 # Fit CTGAN
#      10 ctgan = CTGAN(epochs=10)
# ---> 11 ctgan.fit(iris, categoricals)
#      12
#      13 # Generate the data
#
# /usr/local/lib/python3.11/dist-packages/ctgan/synthesizers/base.py in wrapper(self, *args, **kwargs)
#      48     def wrapper(self, *args, **kwargs):
#      49         if self.random_states is None:
# ---> 50             return function(self, *args, **kwargs)
#      51
#      52         else:
#
# /usr/local/lib/python3.11/dist-packages/ctgan/synthesizers/ctgan.py in fit(self, train_data, discrete_columns, epochs)
#     329                 a ``pandas.DataFrame``, this list should contain the column names.
#     330         """
# --> 331         self._validate_discrete_columns(train_data, discrete_columns)
# ...

# %%
# Обучили Тган на нашем датасете
model = CTGAN(
    epochs=100,  # Количество эпох обучения (можно увеличить для лучшего качества)
    verbose=True  # Вывод процесса обучения
)
model.fit(fich_small)
# Out:
# Gen. (-0.88) | Discrim. (0.28): 100%|██████████| 100/100 [00:14<00:00,  6.86it/s]

# %%
# Сгенерили синтетический датасет из 100 строк
synthetic_data = model.sample(100)

# %%
# Сохранили датасет в csv
synthetic_data.to_csv("synthetic_data.csv", index=False)
synthetic_data.head(100)
